# %%
# !pip install pandasdmx
#!pip install requests_cache
#!pip install pandas_datareader

# %%
import pandas as pd
import datetime as dt
import pandas_datareader.data as web

# %%
start_time = dt.datetime(2021, 1, 1)
end_time = dt.datetime(2022, 2, 1)
df = web.DataReader('MEI_CLI', 'oecd', start_time, end_time)

# oecd = px.Request('OECD')
# data_response = oecd.data(resource_id='MEI_CLI', key='all?startTime=2018')
# dir(data_response.data)
# #df = data_response.write(data_response.data.series, parse_time=False)
# #df.to_csv('c:\\Temp\\test_lei.txt', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
# ...

# %%
df.columns.levels[0]  ## show unique list for 0-level multi-index in columns
# Out:
# Index(['Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Bulgaria',
#        'Canada', 'Chile', 'China (People's Republic of)', 'Colombia',
#        'Costa Rica', 'Croatia', 'Cyprus', 'Czech Republic', 'Denmark',
#        'Estonia', 'European Union (27 countries)', 'Finland', 'France', 'G20',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Ireland', 'Israel', 'Italy', 'Japan', 'Korea', 'Latvia', 'Lithuania',
#        'Luxembourg', 'Malta', 'Mexico', 'Netherlands', 'New Zealand', 'Norway',
#        'OECD - Total', 'Poland', 'Portugal', 'Romania', 'Russia',
#        'Saudi Arabia', 'Singapore', 'Slovak Republic', 'Slovenia',
#        'South Africa', 'Spain', 'Sweden', 'Switzerland', 'Türkiye',
#        'United Kingdom', 'United States', 'World'],
#       dtype='object', name='Country')

# %%
df['Argentina','Women','Total']  ##filtering using Multiindex
# Out:
# Time
# 2000-01-01    18761959.0
# 2001-01-01    18956492.0
# 2002-01-01    19155648.0
# 2003-01-01    19359551.0
# 2004-01-01    19568343.0
# 2005-01-01    19782161.0
# 2006-01-01    19985925.0
# 2007-01-01    20194243.0
# 2008-01-01    20407235.0
# 2009-01-01    20625028.0
# 2010-01-01    20847749.0
# 2011-01-01    21080699.0
# 2012-01-01    21312880.0
# 2013-01-01    21543898.0
# 2014-01-01    21773297.0
# 2015-01-01    22000620.0
# 2016-01-01    22225898.0
# 2017-01-01    22449188.0
# 2018-01-01    22670130.0
# 2019-01-01    22888380.0
# 2020-01-01    23103631.0
# 2021-01-01    23315929.0
# Name: (Argentina, Women, Total), dtype: float64

# %%
import json
import requests
import pandas as pd

# %%
df = pd.read_csv('https://stats.oecd.org/SDMX-JSON/data/MEI_CLI/all/OECD?contentType=csv')
df.head()
# Out:
# C:\Users\gredi\AppData\Local\Temp\ipykernel_20112\3431856878.py:1: DtypeWarning: Columns (12,13,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://stats.oecd.org/SDMX-JSON/data/MEI_CLI/all/OECD?contentType=csv')
#            SUBJECT                              Subject LOCATION    Country  \
# 0  LORSGPOR_IXOBSA  Original, seasonally adjusted (GDP)      IDN  Indonesia
# 1  LORSGPOR_IXOBSA  Original, seasonally adjusted (GDP)      IDN  Indonesia
# 2  LORSGPOR_IXOBSA  Original, seasonally adjusted (GDP)      IDN  Indonesia
# 3  LORSGPOR_IXOBSA  Original, seasonally adjusted (GDP)      IDN  Indonesia
# 4  LORSGPOR_IXOBSA  Original, seasonally adjusted (GDP)      IDN  Indonesia
#
#   FREQUENCY Frequency  TIME  Time Unit Code   Unit  PowerCode Code PowerCode  \
# 0         A    Annual  1990  1990       IDX  Index               0     Units
# 1         A    Annual  1991  1991       IDX  Index               0     Units
# ...

# %%
df[df.FREQUENCY=='M']['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg', 'Mexico',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Slovak Republic', 'Spain', 'Sweden', 'Switzerland', 'Türkiye',
#        'United Kingdom', 'United States', 'Euro area', 'Brazil', 'Chile',
#        "China (People's Republic of)", 'Estonia', 'India', 'Indonesia',
#        'Russia', 'Slovenia', 'South Africa', 'OECD + Major Six NME',
#        'Major Five Asia', 'G7', 'OECD - Europe', 'OECD - Total',
#        'Four Big European', 'NAFTA', 'Euro area (19 countries)', 'Israel',
#        'Latvia', 'OECD total excluding the euro area', 'Lithuania',
#        'Colombia', 'Costa Rica', 'G20',
#        'European Union – 27 countries (from 01/02/2020)',
#        'European Union'], dtype=object)

# %%
df.Subject.unique()
# Out:
# array(['Original, seasonally adjusted (GDP)',
#        '12-month rate of change of the reference series (GDP)',
#        'OECD Standardised BCI, Amplitude adjusted (Long term average=100), sa',
#        'OECD Standardised CCI, Amplitude adjusted (Long term average=100), sa',
#        'Amplitude adjusted (CLI)', 'Normalised (CLI)',
#        'Trend restored (CLI)',
#        '12-month rate of change of the trend restored CLI',
#        'Ratio to trend (GDP)', 'Normalised (GDP)', 'Trend (GDP)'],
#       dtype=object)

# %%
df.to_csv('data/OECD_CLI.csv')

# %%
df_MEI = pd.read_csv('https://stats.oecd.org/SDMX-JSON/data/MEI/USA...M/all/OECD?contentType=csv')
# Out:
# C:\Users\gredi\AppData\Local\Temp\ipykernel_20112\261127876.py:1: DtypeWarning: Columns (14,15,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_MEI = pd.read_csv('https://stats.oecd.org/SDMX-JSON/data/MEI/USA...M/all/OECD?contentType=csv')

# %%
df_MEI.to_csv('data/MEI_US.csv')

# %%
country_list=['USA', 'KOR', 'JPN']

for country in country_list:
    df_MEI=pd.read_csv('https://stats.oecd.org/SDMX-JSON/data/MEI/{}...M/all/OECD?contentType=csv'.format(country))
    df_MEI.to_csv('data/MEI_{}.csv'.format(country))
# Out:
# array(['Labour Compensation > Earnings > Private sector > Hourly',
#        'International Trade > Net trade > Value (goods) > Total',
#        'Business tendency surveys (manufacturing) > Employment > Future Tendency > National indicator',
#        'International Trade > Imports > Value (goods) > Total',
#        'Production > Manufacturing > Total manufacturing > Total manufacturing',
#        'Sales > Retail trade > Total retail trade > Volume',
#        'Consumer Price Index > All items > All items: wage earners > Total',
#        'Consumer Price Index > OECD Groups > All items non-food non-energy > Total',
#        'Monetary aggregates and their components > Broad money and components > M3 > M3',
#        'Sales > Retail trade > Car registration > Passenger cars',
#        'Interest Rates > 3-month or 90-day rates and yields > Eurodollar deposits > Total',
#        'Interest Rates > Immediate rates (< 24 hrs) > Call money/interbank rate > Total',
# ...

# %%
import cif as cif

# %%
data, subjects, measures = cif.createDataFrameFromOECD(countries = ['USA'], dsname = 'MEI', frequency = 'M')

# %%
df_MEI.columns
# Out:
# Index(['LOCATION', 'Country', 'SUBJECT', 'Subject', 'MEASURE', 'Measure',
#        'FREQUENCY', 'Frequency', 'TIME', 'Time', 'Unit Code', 'Unit',
#        'PowerCode Code', 'PowerCode', 'Reference Period Code',
#        'Reference Period', 'Value', 'Flag Codes', 'Flags'],
#       dtype='object')

# %%
df_MEI[df_MEI.FREQUENCY=='M'].shape
# Out:
# (712103, 19)
