# %% [markdown]
# # LSTM/GRU modeling
#
# ## 1. Modeling
# Used Functions
# - create_dataset(): transform X dataset into dataset splitted in timestep-unit
# - BlockingTimeSeriesSplit(): make train-validation split object
# ** reference : https://gmnam.tistory.com/230#:~:text=class%20BlockingTimeSeriesSplit%28%29%3A%20def%20__init__%28self%2C%20n_splits%29%3A%20self.n_splits%20%3D%20n_splits,indices%20%5Bstart%3A%20mid%5D%2C%20indices%20%5Bmid%20%2B%20margin%3A%20stop%5D
# - make_split(): train-validation split using BlockedTimeSeriesSplit() object
# - make_lstm_model(): make lstm model structure
# - make_gru_model(): make gru model structure
# - grid_search(): execute grid search for lstm/gru model and save the models and performance results in history_dict.pkl in the designated folder path
#
# ## 2. Model Selection
# Outcomes
# * df_results.pkl & df_selection.pkl
# -- df_results: concatenate all candidate LSTM/GRU models result by model specification and each validation
# -- df_selection: concatenate all candidate LSTM/GRU models result by model specification
# * using df_selection for selecting the best model among all candidate models

# %% [markdown]
# ##1. Modeling

# %% [markdown]
# ### Set up

# %%
import tensorflow as tf
from tensorflow import keras

import os
import random
import tempfile
import pickle

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import numpy as np
import pandas as pd
import seaborn as sns

import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras.utils.np_utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import AUC, Recall, Precision
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from keras import backend as K

# %%
## import data and metadata

import os, sys
from google.colab import drive
drive.mount('/content/drive')
path='drive/MyDrive/Capstone(Team10)/code'


file = tf.keras.utils

with open(path+'/data/X_data_full.pkl','rb') as f:
  X_data=pickle.load(f)

raw_df = pd.read_csv(path+'/data/rawdata_USA.csv', index_col=0, parse_dates=True)
raw_df.index.name='date'

metadata=pd.read_csv(path+'/data/metadata_final.csv')

X_data.head(5)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#             LCEAPR01  XTIMVA01  PRMNTO01  MABMM301  PRCNTO01  STMNIS01  \
# date
# 1973-01-01  0.004975  0.047149  0.007775  0.009922  0.013699 -0.006349
# 1973-02-01  0.002478  0.044624  0.015954  0.004679  0.020691 -0.006390
# 1973-03-01  0.004938 -0.012775  0.001725  0.001473  0.014144  0.006390
# 1973-04-01  0.004914 -0.009876 -0.001709  0.005382 -0.027771  0.006349
# 1973-05-01  0.004890  0.062043  0.006343  0.008624 -0.010260  0.000000
#
#             SLWHTO02  ODMNTO02  XTEXVA01  CCRETT01  ...  IRLTLT01  IR3TCD01  \
# date                                                ...
# 1973-01-01  0.040962  0.014942  0.084607 -0.011478  ...      0.10      0.38
# 1973-02-01  0.016314  0.023197  0.022962 -0.041932  ...      0.18      0.53
# 1973-03-01  0.019215  0.022260  0.046380 -0.035349  ...      0.07      0.71
# 1973-04-01  0.021154 -0.008716  0.033822  0.002986  ...     -0.04      0.26
# 1973-05-01  0.014101  0.006697  0.012248 -0.009481  ...      0.18      0.24
#
#              BSPRTE02  LREMTTTT  LRHU24TT  LRUNTTTT  BSCURT02  3MTBILL  10YT  \
# date
# 1973-01-01   2.569360      -0.2      -1.1      -0.3    0.3890     0.34  0.10
# 1973-02-01  -6.665425       0.4       0.7       0.1    1.1154     0.19  0.18
# 1973-03-01   0.992926       0.3      -0.5      -0.1   -0.1107     0.49  0.07
# 1973-04-01  -3.104780      -0.1       0.6       0.1   -0.4168     0.17 -0.04
# 1973-05-01 -13.030239       0.0      -0.3      -0.1    0.2500     0.10  0.18
#
#             103SPREAD
# date
# 1973-01-01       1.05
# 1973-02-01       1.04
# 1973-03-01       0.62
# 1973-04-01       0.41
# 1973-05-01       0.49
#
# [5 rows x 45 columns]

# %% [markdown]
# ### Create Dataset X split into timestep unit
#
# * input shape = ( X=[#obs, #feature] , y=[#obs, 1], time_steps=t )
# * output shape = ( [#obs-(t-1), t, #feature], [#obs-(t-1), ] )

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []

    if type(Xs)==pd.core.frame.DataFrame:
      for i in range(len(X) - time_steps + 1):
          v = X.iloc[i:(i + time_steps)].values
          Xs.append(v)
          ys.append(y.iloc[i + time_steps-1].values)
          Xs=np.array(Xs)
          ys=np.array(ys)

    else:
      for i in range(len(X) - time_steps + 1):
          v = X[i:(i + time_steps)]
          Xs.append(v)
          ys.append(y[i + time_steps-1])

    return np.array(Xs), np.array(ys)

# %%
a, b=create_dataset(X_data, raw_df['y_oecd'][-600-6:-6], 24)
a.shape, b.shape
# Out:
# ((577, 24, 45), (577,))

# %% [markdown]
# ### Make BlockSplit object and Split function

# %%
class BlockingTimeSeriesSplit():
    def __init__(self, n_splits):
        self.n_splits = n_splits

    def get_n_splits(self, groups):
        return self.n_splits

    def split(self, X, y=None, groups=None):
        n_samples = len(X)
        k_fold_size = n_samples // self.n_splits
        indices = np.arange(n_samples)

        margin = 0
        for i in range(self.n_splits):
            start = i * k_fold_size
            stop = start + k_fold_size
            mid = int(0.8 * (stop - start)) + start
            yield indices[start: mid], indices[mid + margin: stop]

# %%
cmap_data = plt.cm.Paired
cmap_cv = plt.cm.coolwarm
plt.style.use('fivethirtyeight')

## make index for train, validation dataset
def make_split(X_data, n_splits, test_year):
  train_idxs=[]
  val_idxs=[]

  tss=BlockingTimeSeriesSplit(n_splits=n_splits)

  for train_idx, val_idx in tss.split(X_data[:-(test_year*12)]):
    train_idxs.append(train_idx)
    val_idxs.append(val_idx)

  return train_idxs, val_idxs

## plot the result of blocked split
def plot_cv_indices(cv, X, n_splits, lw=10):

    fig, ax = plt.subplots()

    for ii, (tr, tt) in enumerate(cv.split(X=X)):
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=lw, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)

    yticklabels = list(range(n_splits))
    ax.set(yticks=np.arange(n_splits) + .5, yticklabels=yticklabels,
           xlabel='Sample index', ylabel="CV iteration",
           ylim=[n_splits+0.1, -.1], xlim=[0, len(X)])
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)

    ax.legend([Patch(color=cmap_cv(.8)), Patch(color=cmap_cv(.02))],
          ['Testing set', 'Training set'], loc=(1.02, .8))

# %% [markdown]
# ### Make LSTM/GRU model
#
# * fitting with X, y where t is timestep length
# -- X.shape=[#obs-(t-1), t, #feature]
# -- y.shape=[#obs-(t-1), #class]
# -- output.shape=[#obs-(t-1), #class]: ex.column 0 will show the predicted probability for class 0

# %%
def make_lstm_model(num_layer, X_train, nc, metrics, loss_type, dropout, activation, regularizer):
    model = Sequential()
    model.add(LSTM(num_layer, input_shape=(X_train.shape[1], X_train.shape[2]), dropout=dropout, activation=activation, kernel_regularizer=regularizer))  ##input_shape=(X_train.shape[1], X_train.shape[2])
    model.add(Dense(nc, activation='softmax'))
    model.compile(loss=loss_type, optimizer='adam', metrics=metrics)
    return model

def make_gru_model(num_layer, X_train, nc, metrics, loss_type, dropout, activation, regularizer):
    model = Sequential()
    model.add(GRU(num_layer, input_shape=(X_train.shape[1], X_train.shape[2]), dropout=dropout, activation=activation, kernel_regularizer=regularizer))  ##input_shape=(X_train.shape[1], X_train.shape[2])
    model.add(Dense(nc, activation='softmax'))
    model.compile(loss=loss_type, optimizer='adam', metrics=metrics)
    return model

# %% [markdown]
# ### Make Grid Search function which trains the model and automatically save the model and performance results on designated path

# %%
######################run this cell only for training whole models####################################

## set the random seed for reproducibility
np.random.seed(699)

os.environ['PYTHONHASHSEED'] = '699'
random.seed(699)

tf.compat.v1.set_random_seed(699)
tf.keras.utils.set_random_seed(699)

session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

def grid_search(path, X_data, y_data, model_type, y_type, n_splits, test_year, nl=[10, 20, 30, 40, 50, 70, 100],
                epochs=[100], batch_sizes=[6], time_steps=[12, 18, 24], es=True, dropouts=[0.2],  # batch_size=12
                activation='tanh', reg_methods=[None, 'L1','L1'], reg_factors=[0, 0.01, 0.03]):

## comment this part when the cell unexpected stop in the midst of grid-search
 results = []
  history_dict={'model':[], 'val':[], 'history':[],
                'auc': [],
                'recall_0': [], \
                'recall_1': [], \
                'recall_2': [], \
                'final_auc':[], \
                'final_recall_0':[],
                'final_recall_1':[],
                'final_recall_2':[],}

## uncomment this part when the cell unexpected stop in the midst of grid-search
  # with open(path+'/history_dict.pkl','rb') as f:
  #   history_dict=pickle.load(f)

  best_auc = 0
  best_params = None
  nc=len(y_data.unique())

  train_idxs, val_idxs = make_split(X_data, n_splits, test_year)

  for time_step in time_steps:
    loss_type = 'categorical_crossentropy'
    for num_epochs in epochs:
      for batch_size in batch_sizes:
        for num_layer in nl:
          for dropout in dropouts:
            for (method, factor) in zip(reg_methods, reg_factors):
              if method=='L1':
                reg=regularizers.L1(factor)
              elif method=='L2':
                reg=regularizers.L2(factor)
              else:
                reg=None

              if method==None:
                model_name='clf_{}_{}_{}_b{}_ep{}_h{}_d{}_{}'.format(y_type, model_type, time_step, batch_size, num_epochs, num_layer, dropout, method)
              else:
                model_name='clf_{}_{}_{}_b{}_ep{}_h{}_d{}_{}_{}'.format(y_type, model_type, time_step, batch_size, num_epochs, num_layer, dropout, method, factor)


              for i, (train_idx, val_idx) in enumerate(zip(train_idxs, val_idxs)):

                X_train=X_data.iloc[list(train_idx)]
                y_train=y_data.iloc[list(train_idx)]
                X_val=X_data.iloc[list(val_idx)]
                y_val=y_data.iloc[list(val_idx)]

                ##standard scaling
                scaler = StandardScaler()
                X_train = scaler.fit_transform(X_train)
                X_val = scaler.transform(X_val)

                ##make dataset to feed into the model (dataset split into timestep unit)
                trainx, trainy = create_dataset(X_train, y_train, time_step)
                valx, valy = create_dataset(X_val, y_val, time_step)
                trainy = to_categorical(trainy, num_classes=nc)
                valy = to_categorical(valy, num_classes=nc)

                ##assign metrics to calculate for each validation set
                if y_type!='y_agg':

                  metrics=[AUC(curve='ROC', multi_label=True, num_labels=2),  ##'Accuracy','Recall','Precision',
                          Recall(class_id=0, name='recall_0'),
                          Recall(class_id=1, name='recall_1')]

                else:

                  metrics=[AUC(curve='ROC', multi_label=True, num_labels=2),  ##'Accuracy','Recall','Precision',
                          Recall(class_id=0, name='recall_0'),
                          Recall(class_id=1, name='recall_1'),
                          Recall(class_id=2, name='recall_2')]

                # set model type
                if model_type=='lstm':
                  model=make_lstm_model(num_layer, trainx, nc, metrics, loss_type, dropout, activation=activation, regularizer=reg)
                else:
                  model=make_gru_model(num_layer, trainx, nc, metrics, loss_type, dropout, activation=activation, regularizer=reg)

                ## execute early stop according to recall for positive class
                if es==True:
                  early_stop = EarlyStopping(monitor='recall_1', patience=5, verbose=1,
                                            restore_best_weights=True)   ##restore best_weight=True
                  history=model.fit(trainx, trainy, epochs=num_epochs, batch_size=batch_size, callbacks=[early_stop])
                else:
                  history=model.fit(trainx, trainy, epochs=num_epochs, batch_size=batch_size)

                # evaluation of the model for each validation set
                scores = model.evaluate(valx, valy, verbose=0)

                # store the evaluation results in history_dict
                history_dict['model'].append(model_name)
                history_dict['val'].append(i)
                history_dict['history'].append(history)
                history_dict['auc'].append(scores[1])
                history_dict['recall_0'].append(scores[2])
                history_dict['recall_1'].append(scores[3])

                if y_type=='y_agg':
                  history_dict['recall_2'].append(scores[4])
                else:
                  history_dict['recall_2'].append(-100)

              X_test=X_data.iloc[-test_year*12-time_step+1:]   ##revising this part: -time_step+1
              y_test=y_data.iloc[-test_year*12-time_step+1:]   ##revising this part: -time_step+1

              X_ft=X_data.iloc[:-test_year*12]
              y_ft=y_data.iloc[:-test_year*12]

              ##standard scaling
              scaler = StandardScaler()
              X_ft = scaler.fit_transform(X_ft)
              X_test = scaler.transform(X_test)

              ##make dataset to feed into the model (dataset split into timestep unit)
              ft_x, ft_y = create_dataset(X_ft, y_ft, time_step)
              testx, testy = create_dataset(X_test, y_test, time_step)
              ft_y = to_categorical(ft_y, num_classes=nc)
              testy = to_categorical(testy, num_classes=nc)

              ##assign metrics to calculate for final test dataset
              if y_type!='y_agg':
                metrics=[AUC(curve='ROC', multi_label=True, num_labels=2),  ##'Accuracy','Recall','Precision',
                        Recall(class_id=0, name='recall_0'),
                        Recall(class_id=1, name='recall_1')]

              else:
                metrics=[AUC(curve='ROC', multi_label=True, num_labels=2),   ##'Accuracy','Recall','Precision',
                        Recall(class_id=0, name='recall_0'),
                        Recall(class_id=1, name='recall_1'),
                        Recall(class_id=2, name='recall_2')]

              ## set model type
              if model_type=='lstm':
                model=make_lstm_model(num_layer, ft_x, nc, metrics, loss_type, dropout, activation=activation, regularizer=reg)
              else:
                model=make_gru_model(num_layer, ft_x, nc, metrics, loss_type, dropout, activation=activation, regularizer=reg)

              ## execute early stop according to recall for positive class
              if es==True:
                early_stop = EarlyStopping(monitor='recall_1', patience=5, verbose=1,
                                          restore_best_weights=True)
                history=model.fit(ft_x, ft_y, epochs=num_epochs, batch_size=batch_size, callbacks=[early_stop])
              else:
                history=model.fit(ft_x, ft_y, epochs=num_epochs, batch_size=batch_size)

              ## evaluation of the model for final test set
              final_scores=model.evaluate(testx, testy, verbose=0)

              ## store the final test results in history_dict
              history_dict['final_auc'].extend([final_scores[1]]*n_splits)
              history_dict['final_recall_0'].extend([final_scores[2]]*n_splits)
              history_dict['final_recall_1'].extend([final_scores[3]]*n_splits)
              if y_type=='y_agg':
                history_dict['final_recall_2'].extend([final_scores[4]]*n_splits)
              else:
                history_dict['final_recall_2'].extend([-100]*n_splits)

              ## save validation and test results as history_dict.pkl file
              with open(path+'/history_dict.pkl','wb') as f:
                pickle.dump(history_dict, f)

              ## save trained model
              model.save(path+'/{}.h5'.format(model_name))

# %% [markdown]
# ### Execute Grid Search
# * Make directory for assigned target type, model type and early stopping options.
# * for each directory execute grid search and save the models as h5 format and results into history_dict.pkl file.

# %%
######################run this cell only for training whole models####################################

########### assign target type, model type, and early stopping option(T/F) in interest ########################
### below example will return 4 folders with saved grid searched models and history_dict.pkl file ###
ytype_list=['oecd','oecd','oecd','oecd']
modeltype_list=['lstm', 'gru', 'lstm', 'gru']
es_list=[True, True, False, False]
###############################################################################################################

cases=list(zip(ytype_list, modeltype_list, es_list))

for (ytype, model_type, es) in cases:

  ## set random seed for environment
  np.random.seed(699)
  os.environ['PYTHONHASHSEED'] = '699'
  random.seed(699)

  tf.compat.v1.set_random_seed(699)
  tf.keras.utils.set_random_seed(699)

  session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
  sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
  tf.compat.v1.keras.backend.set_session(sess)

  ## assign threshold for minimum available years for features
  threshold=50

  y_type='y_{}'.format(ytype)
  n_splits=3
  test_year=5

  y=raw_df[y_type]
  y_data=y[-(threshold*12+6):-6]

  ## set folder path and generate directory if not exists
  if es==True:
    folder_path=path+'/model/change_test{}_{}_{}_es'.format(test_year, ytype, model_type)
  else:
    folder_path=path+'/model/change_test{}_{}_{}'.format(test_year, ytype, model_type)

  if not os.path.exists(folder_path):
    os.mkdir(folder_path)

  ## execute grid search
  ########### assign hyperparameters in interest #############################################################
  grid_search(folder_path, X_data, y_data, model_type, y_type, n_splits, test_year, nl=[10, 20, 30, 40, 50, 70, 100],
              epochs=[100], batch_sizes=[12], time_steps=[12, 18, 24], es=es, dropouts=[0.2],
              activation='tanh', reg_methods=[None, 'L1','L1'], reg_factors=[0, 0.01, 0.03])
  ############################################################################################################
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 16ms/step - loss: 0.7385 - auc_57: 0.3438 - recall_0: 0.2857 - recall_1: 0.3857
# Epoch 2/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6872 - auc_57: 0.5789 - recall_0: 0.5397 - recall_1: 0.5714
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6610 - auc_57: 0.6406 - recall_0: 0.6032 - recall_1: 0.6286
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6416 - auc_57: 0.7025 - recall_0: 0.6349 - recall_1: 0.6429
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5950 - auc_57: 0.8108 - recall_0: 0.7619 - recall_1: 0.7429
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5904 - auc_57: 0.8799 - recall_0: 0.8182 - recall_1: 0.7857Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5730 - auc_57: 0.8694 - recall_0: 0.8095 - recall_1: 0.7857
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 11ms/step - loss: 0.7166 - auc_58: 0.5213 - recall_0: 0.4396 - recall_1: 0.5714
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6850 - auc_58: 0.5744 - recall_0: 0.5165 - recall_1: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6703 - auc_58: 0.5992 - recall_0: 0.5604 - recall_1: 0.5476
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6565 - auc_58: 0.6421 - recall_0: 0.6374 - recall_1: 0.5714
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6346 - auc_58: 0.6698 - recall_0: 0.6703 - recall_1: 0.5714
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5786 - auc_58: 0.7698 - recall_0: 0.8132 - recall_1: 0.6429
# Epoch 7/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5800 - auc_58: 0.7361 - recall_0: 0.7917 - recall_1: 0.6667Restoring model weights from the end of the best epoch: 2.
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5941 - auc_58: 0.7199 - recall_0: 0.7692 - recall_1: 0.6190
# Epoch 7: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 15ms/step - loss: 0.7426 - auc_59: 0.4008 - recall_0: 0.4301 - recall_1: 0.5000
# Epoch 2/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7090 - auc_59: 0.4739 - recall_0: 0.4946 - recall_1: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6759 - auc_59: 0.5285 - recall_0: 0.6022 - recall_1: 0.3250
# Epoch 4/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6540 - auc_59: 0.6238 - recall_0: 0.6667 - recall_1: 0.4750
# Epoch 5/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6070 - auc_59: 0.7516 - recall_0: 0.7204 - recall_1: 0.5500
# Epoch 6/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5959 - auc_59: 0.7538 - recall_0: 0.8280 - recall_1: 0.4750
# Epoch 7/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5763 - auc_59: 0.7940 - recall_0: 0.8495 - recall_1: 0.5750
# Epoch 8/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5719 - auc_59: 0.7545 - recall_0: 0.8000 - recall_1: 0.6364Restoring model weights from the end of the best epoch: 3.
# 4/4 [==============================] - 0s 20ms/step - loss: 0.5617 - auc_59: 0.7978 - recall_0: 0.8817 - recall_1: 0.5750
# Epoch 8: early stopping
# Epoch 1/100
# 15/15 [==============================] - 3s 8ms/step - loss: 0.6928 - auc_60: 0.5859 - recall_0: 0.5119 - recall_1: 0.6229
# Epoch 2/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6137 - auc_60: 0.7243 - recall_0: 0.7201 - recall_1: 0.6102
# Epoch 3/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5610 - auc_60: 0.7916 - recall_0: 0.8294 - recall_1: 0.6271
# Epoch 4/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5330 - auc_60: 0.8168 - recall_0: 0.8805 - recall_1: 0.6186
# Epoch 5/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5018 - auc_60: 0.8453 - recall_0: 0.9078 - recall_1: 0.6441
# Epoch 6/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4850 - auc_60: 0.8584 - recall_0: 0.9113 - recall_1: 0.6525
# Epoch 7/100
# 15/15 [==============================] - ETA: 0s - loss: 0.4570 - auc_60: 0.8773 - recall_0: 0.9215 - recall_1: 0.6610Restoring model weights from the end of the best epoch: 2.
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4570 - auc_60: 0.8773 - recall_0: 0.9215 - recall_1: 0.6610
# Epoch 7: early stopping
# Epoch 1/100
# 4/4 [==============================] - 6s 13ms/step - loss: 3.2934 - auc_61: 0.0812 - recall_0: 0.0794 - recall_1: 0.2143
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 3.1923 - auc_61: 0.0880 - recall_0: 0.1587 - recall_1: 0.2000
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 3.1192 - auc_61: 0.1246 - recall_0: 0.1111 - recall_1: 0.3000
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 3.0374 - auc_61: 0.1348 - recall_0: 0.1587 - recall_1: 0.2429
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.9427 - auc_61: 0.1805 - recall_0: 0.1905 - recall_1: 0.2857
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.8626 - auc_61: 0.2234 - recall_0: 0.3333 - recall_1: 0.3143
# Epoch 7/100
# 1/4 [======>.......................] - ETA: 0s - loss: 2.8303 - auc_61: 0.2309 - recall_0: 0.1667 - recall_1: 0.3750Restoring model weights from the end of the best epoch: 2.
# 4/4 [==============================] - 0s 13ms/step - loss: 2.8023 - auc_61: 0.2593 - recall_0: 0.3333 - recall_1: 0.4143
# Epoch 7: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 13ms/step - loss: 2.9554 - auc_62: 0.7945 - recall_0: 0.7802 - recall_1: 0.7619
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.8805 - auc_62: 0.7976 - recall_0: 0.7912 - recall_1: 0.7381
# Epoch 3/100
# 4/4 [==============================] - 0s 14ms/step - loss: 2.8115 - auc_62: 0.7997 - recall_0: 0.7582 - recall_1: 0.7857
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.7264 - auc_62: 0.8490 - recall_0: 0.8242 - recall_1: 0.7381
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.6717 - auc_62: 0.8373 - recall_0: 0.8132 - recall_1: 0.7143
# Epoch 6/100
# 4/4 [==============================] - 0s 15ms/step - loss: 2.5790 - auc_62: 0.8838 - recall_0: 0.8791 - recall_1: 0.8333
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.5205 - auc_62: 0.8505 - recall_0: 0.8901 - recall_1: 0.8333
# Epoch 8/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.4606 - auc_62: 0.8539 - recall_0: 0.8901 - recall_1: 0.8095
# Epoch 9/100
# 4/4 [==============================] - 0s 12ms/step - loss: 2.3880 - auc_62: 0.8810 - recall_0: 0.8791 - recall_1: 0.8333
# Epoch 10/100
# 1/4 [======>.......................] - ETA: 0s - loss: 2.3173 - auc_62: 0.9709 - recall_0: 0.9200 - recall_1: 0.8182Restoring model weights from the end of the best epoch: 5.
# 4/4 [==============================] - 0s 14ms/step - loss: 2.3194 - auc_62: 0.8817 - recall_0: 0.9231 - recall_1: 0.7143
# Epoch 10: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 11ms/step - loss: 3.0411 - auc_63: 0.6411 - recall_0: 0.5484 - recall_1: 0.5750
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.9738 - auc_63: 0.6375 - recall_0: 0.6022 - recall_1: 0.5750
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.8903 - auc_63: 0.7187 - recall_0: 0.6667 - recall_1: 0.6500
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.8079 - auc_63: 0.7679 - recall_0: 0.7527 - recall_1: 0.7250
# Epoch 5/100
# 4/4 [==============================] - 0s 10ms/step - loss: 2.7378 - auc_63: 0.7831 - recall_0: 0.7634 - recall_1: 0.6500
# Epoch 6/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.6812 - auc_63: 0.7379 - recall_0: 0.7634 - recall_1: 0.5250
# Epoch 7/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.5970 - auc_63: 0.8319 - recall_0: 0.8387 - recall_1: 0.7000
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.5351 - auc_63: 0.8292 - recall_0: 0.8280 - recall_1: 0.6750
# Epoch 9/100
# 4/4 [==============================] - 0s 10ms/step - loss: 2.4648 - auc_63: 0.8571 - recall_0: 0.8710 - recall_1: 0.6250
# Epoch 10/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.4015 - auc_63: 0.8496 - recall_0: 0.8602 - recall_1: 0.6000
# Epoch 11/100
# 1/4 [======>.......................] - ETA: 0s - loss: 2.3358 - auc_63: 0.9091 - recall_0: 0.9200 - recall_1: 0.6364Restoring model weights from the end of the best epoch: 6.
# 4/4 [==============================] - 0s 14ms/step - loss: 2.3330 - auc_63: 0.8739 - recall_0: 0.8925 - recall_1: 0.6250
# Epoch 11: early stopping
# Epoch 1/100
# 15/15 [==============================] - 3s 11ms/step - loss: 3.0205 - auc_64: 0.5545 - recall_0: 0.5154 - recall_1: 0.5508
# Epoch 2/100
# 15/15 [==============================] - 0s 9ms/step - loss: 2.7709 - auc_64: 0.6348 - recall_0: 0.6621 - recall_1: 0.5254
# Epoch 3/100
# 15/15 [==============================] - 0s 7ms/step - loss: 2.5216 - auc_64: 0.7169 - recall_0: 0.7509 - recall_1: 0.5678
# Epoch 4/100
# 15/15 [==============================] - 0s 8ms/step - loss: 2.2937 - auc_64: 0.7630 - recall_0: 0.8157 - recall_1: 0.5593
# Epoch 5/100
# 15/15 [==============================] - 0s 9ms/step - loss: 2.0711 - auc_64: 0.8044 - recall_0: 0.8362 - recall_1: 0.5678
# Epoch 6/100
# 15/15 [==============================] - 0s 8ms/step - loss: 1.8601 - auc_64: 0.8398 - recall_0: 0.8737 - recall_1: 0.6017
# Epoch 7/100
# 14/15 [===========================>..] - ETA: 0s - loss: 1.6747 - auc_64: 0.8518 - recall_0: 0.8968 - recall_1: 0.6054Restoring model weights from the end of the best epoch: 2.
# 15/15 [==============================] - 0s 9ms/step - loss: 1.6719 - auc_64: 0.8521 - recall_0: 0.9010 - recall_1: 0.6017
# Epoch 7: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 12ms/step - loss: 7.7910 - auc_65: 0.4398 - recall_0: 0.3810 - recall_1: 0.4571
# Epoch 2/100
# 4/4 [==============================] - 0s 15ms/step - loss: 7.5619 - auc_65: 0.5493 - recall_0: 0.6349 - recall_1: 0.4857
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 7.3463 - auc_65: 0.6461 - recall_0: 0.6825 - recall_1: 0.5857
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 7.1349 - auc_65: 0.7151 - recall_0: 0.7619 - recall_1: 0.6286
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 6.9279 - auc_65: 0.7751 - recall_0: 0.8254 - recall_1: 0.6143
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 6.7588 - auc_65: 0.8555 - recall_0: 0.9091 - recall_1: 0.7143Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 13ms/step - loss: 6.7136 - auc_65: 0.8406 - recall_0: 0.9206 - recall_1: 0.6857
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 11ms/step - loss: 7.9123 - auc_66: 0.4294 - recall_0: 0.4066 - recall_1: 0.4524
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 7.6990 - auc_66: 0.4349 - recall_0: 0.5385 - recall_1: 0.4048
# Epoch 3/100
# 4/4 [==============================] - 0s 15ms/step - loss: 7.4631 - auc_66: 0.4999 - recall_0: 0.6044 - recall_1: 0.4286
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 7.2771 - auc_66: 0.4762 - recall_0: 0.5604 - recall_1: 0.4048
# Epoch 5/100
# 4/4 [==============================] - 0s 10ms/step - loss: 7.0758 - auc_66: 0.5228 - recall_0: 0.5934 - recall_1: 0.5238
# Epoch 6/100
# 4/4 [==============================] - 0s 12ms/step - loss: 6.8565 - auc_66: 0.5671 - recall_0: 0.6923 - recall_1: 0.4048
# Epoch 7/100
# 4/4 [==============================] - 0s 10ms/step - loss: 6.6541 - auc_66: 0.5963 - recall_0: 0.7033 - recall_1: 0.3810
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 6.4467 - auc_66: 0.6376 - recall_0: 0.7912 - recall_1: 0.5238
# Epoch 9/100
# 4/4 [==============================] - 0s 21ms/step - loss: 6.2592 - auc_66: 0.6349 - recall_0: 0.8352 - recall_1: 0.4762
# Epoch 10/100
# 4/4 [==============================] - 0s 13ms/step - loss: 6.0619 - auc_66: 0.6974 - recall_0: 0.8242 - recall_1: 0.5238
# Epoch 11/100
# 4/4 [==============================] - 0s 13ms/step - loss: 5.8670 - auc_66: 0.7262 - recall_0: 0.8352 - recall_1: 0.5000
# Epoch 12/100
# 1/4 [======>.......................] - ETA: 0s - loss: 5.7342 - auc_66: 0.7726 - recall_0: 0.9130 - recall_1: 0.6154Restoring model weights from the end of the best epoch: 7.
# 4/4 [==============================] - 0s 12ms/step - loss: 5.6780 - auc_66: 0.7397 - recall_0: 0.8901 - recall_1: 0.5476
# Epoch 12: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 11ms/step - loss: 7.7755 - auc_67: 0.3578 - recall_0: 0.4839 - recall_1: 0.3250
# Epoch 2/100
# 4/4 [==============================] - 0s 10ms/step - loss: 7.5615 - auc_67: 0.3953 - recall_0: 0.5054 - recall_1: 0.3750
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 7.3407 - auc_67: 0.4798 - recall_0: 0.5484 - recall_1: 0.3250
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 7.1328 - auc_67: 0.4546 - recall_0: 0.6452 - recall_1: 0.3500
# Epoch 5/100
# 4/4 [==============================] - 0s 10ms/step - loss: 6.9184 - auc_67: 0.5603 - recall_0: 0.6667 - recall_1: 0.3750
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 6.8412 - auc_67: 0.3545 - recall_0: 0.6400 - recall_1: 0.2727Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 12ms/step - loss: 6.7196 - auc_67: 0.5387 - recall_0: 0.7097 - recall_1: 0.3500
# Epoch 6: early stopping
# Epoch 1/100
# 15/15 [==============================] - 3s 8ms/step - loss: 7.5032 - auc_68: 0.4137 - recall_0: 0.5939 - recall_1: 0.3347
# Epoch 2/100
# 15/15 [==============================] - 0s 8ms/step - loss: 6.7294 - auc_68: 0.5101 - recall_0: 0.6997 - recall_1: 0.3686
# Epoch 3/100
# 15/15 [==============================] - 0s 9ms/step - loss: 6.0042 - auc_68: 0.6026 - recall_0: 0.8157 - recall_1: 0.3220
# Epoch 4/100
# 15/15 [==============================] - 0s 10ms/step - loss: 5.3274 - auc_68: 0.6872 - recall_0: 0.8703 - recall_1: 0.3983
# Epoch 5/100
# 15/15 [==============================] - 0s 11ms/step - loss: 4.6934 - auc_68: 0.7689 - recall_0: 0.9317 - recall_1: 0.3390
# Epoch 6/100
# 15/15 [==============================] - 0s 10ms/step - loss: 4.0927 - auc_68: 0.8305 - recall_0: 0.9454 - recall_1: 0.4237
# Epoch 7/100
# 15/15 [==============================] - 0s 10ms/step - loss: 3.5505 - auc_68: 0.8455 - recall_0: 0.9488 - recall_1: 0.4619
# Epoch 8/100
# 13/15 [=========================>....] - ETA: 0s - loss: 3.0801 - auc_68: 0.8462 - recall_0: 0.9291 - recall_1: 0.4953Restoring model weights from the end of the best epoch: 3.
# 15/15 [==============================] - 0s 10ms/step - loss: 3.0457 - auc_68: 0.8582 - recall_0: 0.9352 - recall_1: 0.5085
# Epoch 8: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 13ms/step - loss: 0.6336 - auc_69: 0.7256 - recall_0: 0.7143 - recall_1: 0.5714
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5601 - auc_69: 0.8720 - recall_0: 0.8413 - recall_1: 0.7000
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4785 - auc_69: 0.9695 - recall_0: 0.9524 - recall_1: 0.8714
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4345 - auc_69: 0.9756 - recall_0: 0.9524 - recall_1: 0.8714
# Epoch 5/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4149 - auc_69: 0.9772 - recall_0: 0.9524 - recall_1: 0.8714
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3687 - auc_69: 0.9935 - recall_0: 0.9545 - recall_1: 0.9286Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3591 - auc_69: 0.9882 - recall_0: 0.9683 - recall_1: 0.8857
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 11ms/step - loss: 0.7037 - auc_70: 0.6116 - recall_0: 0.5165 - recall_1: 0.7381
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6566 - auc_70: 0.6801 - recall_0: 0.5934 - recall_1: 0.6667
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6208 - auc_70: 0.7622 - recall_0: 0.6154 - recall_1: 0.7619
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6195 - auc_70: 0.7495 - recall_0: 0.7143 - recall_1: 0.6905
# Epoch 5/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.5750 - auc_70: 0.8189 - recall_0: 0.7912 - recall_1: 0.7381
# Epoch 6/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5377 - auc_70: 0.8862 - recall_0: 0.8791 - recall_1: 0.7857
# Epoch 7/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.5606 - auc_70: 0.7517 - recall_0: 0.8750 - recall_1: 0.5833Restoring model weights from the end of the best epoch: 2.
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5222 - auc_70: 0.8798 - recall_0: 0.9011 - recall_1: 0.7619
# Epoch 7: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 11ms/step - loss: 0.6123 - auc_71: 0.7246 - recall_0: 0.7204 - recall_1: 0.5500
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5776 - auc_71: 0.7849 - recall_0: 0.8065 - recall_1: 0.5250
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5280 - auc_71: 0.8559 - recall_0: 0.8710 - recall_1: 0.5750
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4748 - auc_71: 0.9148 - recall_0: 0.9570 - recall_1: 0.6500
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4569 - auc_71: 0.9215 - recall_0: 0.9570 - recall_1: 0.5500
# Epoch 6/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4174 - auc_71: 0.9593 - recall_0: 0.9570 - recall_1: 0.5750
# Epoch 7/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3621 - auc_71: 0.9576 - recall_0: 1.0000 - recall_1: 0.7500Restoring model weights from the end of the best epoch: 2.
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3866 - auc_71: 0.9570 - recall_0: 0.9785 - recall_1: 0.6750
# Epoch 7: early stopping
# Epoch 1/100
# 15/15 [==============================] - 3s 9ms/step - loss: 0.6958 - auc_72: 0.5495 - recall_0: 0.5085 - recall_1: 0.5763
# Epoch 2/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6005 - auc_72: 0.7728 - recall_0: 0.7884 - recall_1: 0.6229
# Epoch 3/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5305 - auc_72: 0.8517 - recall_0: 0.8908 - recall_1: 0.6737
# Epoch 4/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4821 - auc_72: 0.8833 - recall_0: 0.9010 - recall_1: 0.6780
# Epoch 5/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4367 - auc_72: 0.8997 - recall_0: 0.9181 - recall_1: 0.7161
# Epoch 6/100
# 14/15 [===========================>..] - ETA: 0s - loss: 0.3925 - auc_72: 0.9195 - recall_0: 0.8961 - recall_1: 0.7689Restoring model weights from the end of the best epoch: 1.
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3904 - auc_72: 0.9214 - recall_0: 0.9010 - recall_1: 0.7669
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 12ms/step - loss: 4.6887 - auc_73: 0.3840 - recall_0: 0.5079 - recall_1: 0.3429
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 4.5083 - auc_73: 0.5611 - recall_0: 0.7143 - recall_1: 0.5143
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 4.3482 - auc_73: 0.6956 - recall_0: 0.7778 - recall_1: 0.5143
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 4.1819 - auc_73: 0.7876 - recall_0: 0.8730 - recall_1: 0.6429
# Epoch 5/100
# 4/4 [==============================] - 0s 10ms/step - loss: 4.0345 - auc_73: 0.8317 - recall_0: 0.8730 - recall_1: 0.7429
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 3.8630 - auc_73: 0.9481 - recall_0: 0.9545 - recall_1: 0.7857Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 13ms/step - loss: 3.8789 - auc_73: 0.8739 - recall_0: 0.8889 - recall_1: 0.7143
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 12ms/step - loss: 4.5576 - auc_74: 0.4304 - recall_0: 0.6264 - recall_1: 0.2143
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 4.3905 - auc_74: 0.5595 - recall_0: 0.7033 - recall_1: 0.3333
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 4.2271 - auc_74: 0.6875 - recall_0: 0.7802 - recall_1: 0.4048
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 4.0967 - auc_74: 0.7091 - recall_0: 0.8462 - recall_1: 0.4524
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 3.9582 - auc_74: 0.7590 - recall_0: 0.9231 - recall_1: 0.5238
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 3.8914 - auc_74: 0.7519 - recall_0: 0.8462 - recall_1: 0.3000Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 12ms/step - loss: 3.8115 - auc_74: 0.8416 - recall_0: 0.9121 - recall_1: 0.5952
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 17ms/step - loss: 4.6881 - auc_75: 0.2855 - recall_0: 0.3333 - recall_1: 0.4250
# Epoch 2/100
# 4/4 [==============================] - 0s 15ms/step - loss: 4.5151 - auc_75: 0.3954 - recall_0: 0.4409 - recall_1: 0.4250
# Epoch 3/100
# 4/4 [==============================] - 0s 16ms/step - loss: 4.3501 - auc_75: 0.4460 - recall_0: 0.5806 - recall_1: 0.4000
# Epoch 4/100
# 4/4 [==============================] - 0s 17ms/step - loss: 4.1868 - auc_75: 0.6078 - recall_0: 0.6667 - recall_1: 0.5500
# Epoch 5/100
# 4/4 [==============================] - 0s 16ms/step - loss: 4.0288 - auc_75: 0.7474 - recall_0: 0.7312 - recall_1: 0.5750
# Epoch 6/100
# 4/4 [==============================] - 0s 11ms/step - loss: 3.8936 - auc_75: 0.7728 - recall_0: 0.8280 - recall_1: 0.5500
# Epoch 7/100
# 4/4 [==============================] - 0s 11ms/step - loss: 3.7445 - auc_75: 0.8728 - recall_0: 0.9355 - recall_1: 0.5250
# Epoch 8/100
# 1/4 [======>.......................] - ETA: 0s - loss: 3.6932 - auc_75: 0.8382 - recall_0: 0.9600 - recall_1: 0.5455Restoring model weights from the end of the best epoch: 3.
# 4/4 [==============================] - 0s 13ms/step - loss: 3.6325 - auc_75: 0.8622 - recall_0: 0.9247 - recall_1: 0.4750
# Epoch 8: early stopping
# Epoch 1/100
# 15/15 [==============================] - 4s 14ms/step - loss: 4.3416 - auc_76: 0.6163 - recall_0: 0.6382 - recall_1: 0.5042
# Epoch 2/100
# 15/15 [==============================] - 0s 14ms/step - loss: 3.8267 - auc_76: 0.7639 - recall_0: 0.8020 - recall_1: 0.5551
# Epoch 3/100
# 15/15 [==============================] - 0s 12ms/step - loss: 3.3551 - auc_76: 0.8229 - recall_0: 0.8396 - recall_1: 0.5975
# Epoch 4/100
# 15/15 [==============================] - 0s 12ms/step - loss: 2.9250 - auc_76: 0.8498 - recall_0: 0.8635 - recall_1: 0.6059
# Epoch 5/100
# 15/15 [==============================] - 0s 12ms/step - loss: 2.5292 - auc_76: 0.8719 - recall_0: 0.8771 - recall_1: 0.6610
# Epoch 6/100
# 14/15 [===========================>..] - ETA: 0s - loss: 2.1678 - auc_76: 0.8918 - recall_0: 0.8710 - recall_1: 0.7244Restoring model weights from the end of the best epoch: 1.
# 15/15 [==============================] - 0s 14ms/step - loss: 2.1585 - auc_76: 0.8931 - recall_0: 0.8703 - recall_1: 0.7246
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 14ms/step - loss: 12.0852 - auc_77: 0.7083 - recall_0: 0.6825 - recall_1: 0.6429
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 11.6193 - auc_77: 0.8223 - recall_0: 0.8413 - recall_1: 0.7143
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 11.1998 - auc_77: 0.8512 - recall_0: 0.8730 - recall_1: 0.7714
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 10.7926 - auc_77: 0.8637 - recall_0: 0.8095 - recall_1: 0.7714
# Epoch 5/100
# 4/4 [==============================] - 0s 15ms/step - loss: 10.3699 - auc_77: 0.8978 - recall_0: 0.9524 - recall_1: 0.7714
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 10.0957 - auc_77: 0.8847 - recall_0: 1.0000 - recall_1: 0.7857Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 15ms/step - loss: 9.9890 - auc_77: 0.8833 - recall_0: 0.9524 - recall_1: 0.7857
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 8s 13ms/step - loss: 12.2074 - auc_78: 0.5654 - recall_0: 0.5385 - recall_1: 0.5952
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 11.7510 - auc_78: 0.7119 - recall_0: 0.5604 - recall_1: 0.7619
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 11.3391 - auc_78: 0.7084 - recall_0: 0.6484 - recall_1: 0.6190
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 10.9226 - auc_78: 0.7636 - recall_0: 0.7253 - recall_1: 0.6190
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 10.5313 - auc_78: 0.7832 - recall_0: 0.7363 - recall_1: 0.6190
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 10.2632 - auc_78: 0.8231 - recall_0: 0.8462 - recall_1: 0.6000Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 15ms/step - loss: 10.1171 - auc_78: 0.8460 - recall_0: 0.8132 - recall_1: 0.6667
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 16ms/step - loss: 12.6014 - auc_79: 0.3149 - recall_0: 0.4194 - recall_1: 0.3250
# Epoch 2/100
# 4/4 [==============================] - 0s 17ms/step - loss: 12.1556 - auc_79: 0.3859 - recall_0: 0.5484 - recall_1: 0.2500
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 11.7381 - auc_79: 0.4657 - recall_0: 0.5591 - recall_1: 0.3750
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 11.3167 - auc_79: 0.5298 - recall_0: 0.7204 - recall_1: 0.3250
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 10.9108 - auc_79: 0.5913 - recall_0: 0.7634 - recall_1: 0.2000
# Epoch 6/100
# 4/4 [==============================] - 0s 16ms/step - loss: 10.5134 - auc_79: 0.6888 - recall_0: 0.8172 - recall_1: 0.2750
# Epoch 7/100
# 4/4 [==============================] - 0s 14ms/step - loss: 10.1138 - auc_79: 0.7685 - recall_0: 0.8495 - recall_1: 0.4250
# Epoch 8/100
# 4/4 [==============================] - 0s 15ms/step - loss: 9.7321 - auc_79: 0.7930 - recall_0: 0.8925 - recall_1: 0.4000
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 9.3604 - auc_79: 0.7841 - recall_0: 0.9355 - recall_1: 0.4000
# Epoch 10/100
# 1/4 [======>.......................] - ETA: 0s - loss: 9.1213 - auc_79: 0.8698 - recall_0: 0.9583 - recall_1: 0.3333Restoring model weights from the end of the best epoch: 5.
# 4/4 [==============================] - 0s 16ms/step - loss: 8.9899 - auc_79: 0.8414 - recall_0: 0.9462 - recall_1: 0.3500
# Epoch 10: early stopping
# Epoch 1/100
# 15/15 [==============================] - 3s 13ms/step - loss: 11.8490 - auc_80: 0.5008 - recall_0: 0.7099 - recall_1: 0.3220
# Epoch 2/100
# 15/15 [==============================] - 0s 12ms/step - loss: 10.3371 - auc_80: 0.6561 - recall_0: 0.8294 - recall_1: 0.3263
# Epoch 3/100
# 15/15 [==============================] - 0s 12ms/step - loss: 8.9327 - auc_80: 0.7970 - recall_0: 0.9113 - recall_1: 0.4322
# Epoch 4/100
# 15/15 [==============================] - 0s 13ms/step - loss: 7.6379 - auc_80: 0.8285 - recall_0: 0.9215 - recall_1: 0.4788
# Epoch 5/100
# 15/15 [==============================] - 0s 12ms/step - loss: 6.4362 - auc_80: 0.8668 - recall_0: 0.9352 - recall_1: 0.5593
# Epoch 6/100
# 11/15 [=====================>........] - ETA: 0s - loss: 5.4608 - auc_80: 0.8999 - recall_0: 0.9381 - recall_1: 0.6183Restoring model weights from the end of the best epoch: 1.
# 15/15 [==============================] - 0s 12ms/step - loss: 5.3452 - auc_80: 0.8834 - recall_0: 0.9283 - recall_1: 0.6102
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 12ms/step - loss: 0.6064 - auc_81: 0.8077 - recall_0: 0.8254 - recall_1: 0.6286
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5279 - auc_81: 0.9458 - recall_0: 0.9365 - recall_1: 0.8286
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4505 - auc_81: 0.9688 - recall_0: 0.9683 - recall_1: 0.8857
# Epoch 4/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3951 - auc_81: 0.9898 - recall_0: 0.9683 - recall_1: 0.8857
# Epoch 5/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3258 - auc_81: 0.9951 - recall_0: 0.9841 - recall_1: 0.9286
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3018 - auc_81: 0.9935 - recall_0: 0.9545 - recall_1: 0.8571Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2920 - auc_81: 0.9940 - recall_0: 0.9683 - recall_1: 0.8857
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 12ms/step - loss: 0.6910 - auc_82: 0.5777 - recall_0: 0.5385 - recall_1: 0.6190
# Epoch 2/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.6286 - auc_82: 0.7142 - recall_0: 0.6923 - recall_1: 0.6190
# Epoch 3/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5889 - auc_82: 0.7930 - recall_0: 0.8132 - recall_1: 0.6190
# Epoch 4/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5342 - auc_82: 0.8811 - recall_0: 0.8681 - recall_1: 0.6905
# Epoch 5/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5108 - auc_82: 0.9062 - recall_0: 0.8791 - recall_1: 0.6905
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4931 - auc_82: 0.8635 - recall_0: 0.9231 - recall_1: 0.7000Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4445 - auc_82: 0.9385 - recall_0: 0.9231 - recall_1: 0.7857
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 13ms/step - loss: 0.6792 - auc_83: 0.5364 - recall_0: 0.5914 - recall_1: 0.4250
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6025 - auc_83: 0.7445 - recall_0: 0.7957 - recall_1: 0.4750
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5324 - auc_83: 0.8460 - recall_0: 0.8925 - recall_1: 0.4500
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4710 - auc_83: 0.9453 - recall_0: 0.9785 - recall_1: 0.5500
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4352 - auc_83: 0.9461 - recall_0: 0.9570 - recall_1: 0.5500
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4231 - auc_83: 0.9891 - recall_0: 1.0000 - recall_1: 0.3636Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3854 - auc_83: 0.9696 - recall_0: 0.9785 - recall_1: 0.5750
# Epoch 6: early stopping
# Epoch 1/100
# 15/15 [==============================] - 3s 9ms/step - loss: 0.6378 - auc_84: 0.6764 - recall_0: 0.7713 - recall_1: 0.4703
# Epoch 2/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5057 - auc_84: 0.8719 - recall_0: 0.9078 - recall_1: 0.6186
# Epoch 3/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4355 - auc_84: 0.9045 - recall_0: 0.9181 - recall_1: 0.6822
# Epoch 4/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3840 - auc_84: 0.9231 - recall_0: 0.9215 - recall_1: 0.7161
# Epoch 5/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3489 - auc_84: 0.9309 - recall_0: 0.9044 - recall_1: 0.7669
# Epoch 6/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2920 - auc_84: 0.9533 - recall_0: 0.9386 - recall_1: 0.8390Restoring model weights from the end of the best epoch: 1.
# 15/15 [==============================] - 0s 14ms/step - loss: 0.2920 - auc_84: 0.9533 - recall_0: 0.9386 - recall_1: 0.8390
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 13ms/step - loss: 5.7126 - auc_85: 0.7577 - recall_0: 0.6825 - recall_1: 0.7571
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 5.4582 - auc_85: 0.8595 - recall_0: 0.7778 - recall_1: 0.8714
# Epoch 3/100
# 4/4 [==============================] - 0s 17ms/step - loss: 5.2057 - auc_85: 0.9325 - recall_0: 0.8413 - recall_1: 0.8857
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 4.9999 - auc_85: 0.9282 - recall_0: 0.8730 - recall_1: 0.8714
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 4.7804 - auc_85: 0.9450 - recall_0: 0.8889 - recall_1: 0.8857
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 4.6290 - auc_85: 0.9805 - recall_0: 0.8636 - recall_1: 0.8571Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 16ms/step - loss: 4.5810 - auc_85: 0.9552 - recall_0: 0.8889 - recall_1: 0.8571
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 13ms/step - loss: 5.7533 - auc_86: 0.4082 - recall_0: 0.4066 - recall_1: 0.4048
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 5.5325 - auc_86: 0.4911 - recall_0: 0.4945 - recall_1: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 5.2977 - auc_86: 0.6826 - recall_0: 0.6154 - recall_1: 0.6905
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 5.0773 - auc_86: 0.8264 - recall_0: 0.6813 - recall_1: 0.7619
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 4.8651 - auc_86: 0.8912 - recall_0: 0.7692 - recall_1: 0.8095
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 4.7359 - auc_86: 0.9038 - recall_0: 0.8846 - recall_1: 0.8000Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 13ms/step - loss: 4.6591 - auc_86: 0.9197 - recall_0: 0.8791 - recall_1: 0.8095
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 13ms/step - loss: 5.7277 - auc_87: 0.7212 - recall_0: 0.4946 - recall_1: 0.7250
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 5.4742 - auc_87: 0.7992 - recall_0: 0.7527 - recall_1: 0.7000
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 5.2350 - auc_87: 0.8806 - recall_0: 0.8495 - recall_1: 0.7250
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 5.0203 - auc_87: 0.9020 - recall_0: 0.8817 - recall_1: 0.7250
# Epoch 5/100
# 4/4 [==============================] - 0s 14ms/step - loss: 4.8074 - auc_87: 0.9257 - recall_0: 0.9140 - recall_1: 0.6000
# Epoch 6/100
# 4/4 [==============================] - 0s 16ms/step - loss: 4.6034 - auc_87: 0.9353 - recall_0: 0.9355 - recall_1: 0.6500
# Epoch 7/100
# 4/4 [==============================] - 0s 14ms/step - loss: 4.4113 - auc_87: 0.9317 - recall_0: 0.9355 - recall_1: 0.6500
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 4.2216 - auc_87: 0.9440 - recall_0: 0.9677 - recall_1: 0.6250
# Epoch 9/100
# 4/4 [==============================] - 0s 12ms/step - loss: 4.0113 - auc_87: 0.9706 - recall_0: 0.9570 - recall_1: 0.7250
# Epoch 10/100
# 1/4 [======>.......................] - ETA: 0s - loss: 3.9226 - auc_87: 0.9931 - recall_0: 1.0000 - recall_1: 0.5833Restoring model weights from the end of the best epoch: 5.
# 4/4 [==============================] - 0s 14ms/step - loss: 3.8426 - auc_87: 0.9728 - recall_0: 0.9892 - recall_1: 0.6250
# Epoch 10: early stopping
# Epoch 1/100
# 15/15 [==============================] - 3s 11ms/step - loss: 5.5647 - auc_88: 0.6444 - recall_0: 0.6212 - recall_1: 0.6144
# Epoch 2/100
# 15/15 [==============================] - 0s 16ms/step - loss: 4.7859 - auc_88: 0.8501 - recall_0: 0.8908 - recall_1: 0.6059
# Epoch 3/100
# 15/15 [==============================] - 0s 15ms/step - loss: 4.0813 - auc_88: 0.8911 - recall_0: 0.9181 - recall_1: 0.6229
# Epoch 4/100
# 15/15 [==============================] - 0s 14ms/step - loss: 3.4522 - auc_88: 0.9024 - recall_0: 0.9181 - recall_1: 0.6737
# Epoch 5/100
# 15/15 [==============================] - 0s 13ms/step - loss: 2.8938 - auc_88: 0.9013 - recall_0: 0.8976 - recall_1: 0.7627
# Epoch 6/100
# 15/15 [==============================] - 0s 14ms/step - loss: 2.3835 - auc_88: 0.9157 - recall_0: 0.8942 - recall_1: 0.7881
# Epoch 7/100
# 14/15 [===========================>..] - ETA: 0s - loss: 1.9476 - auc_88: 0.9300 - recall_0: 0.9217 - recall_1: 0.7758Restoring model weights from the end of the best epoch: 2.
# 15/15 [==============================] - 0s 15ms/step - loss: 1.9413 - auc_88: 0.9285 - recall_0: 0.9249 - recall_1: 0.7712
# Epoch 7: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 14ms/step - loss: 16.2026 - auc_89: 0.6415 - recall_0: 0.6190 - recall_1: 0.5857
# Epoch 2/100
# 4/4 [==============================] - 0s 16ms/step - loss: 15.5240 - auc_89: 0.8121 - recall_0: 0.8254 - recall_1: 0.6571
# Epoch 3/100
# 4/4 [==============================] - 0s 14ms/step - loss: 14.8938 - auc_89: 0.8574 - recall_0: 0.8413 - recall_1: 0.6571
# Epoch 4/100
# 4/4 [==============================] - 0s 14ms/step - loss: 14.2609 - auc_89: 0.9138 - recall_0: 0.8889 - recall_1: 0.7714
# Epoch 5/100
# 4/4 [==============================] - 0s 15ms/step - loss: 13.6324 - auc_89: 0.9662 - recall_0: 0.9206 - recall_1: 0.8714
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 13.2369 - auc_89: 0.9610 - recall_0: 1.0000 - recall_1: 0.7143Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 24ms/step - loss: 13.0427 - auc_89: 0.9576 - recall_0: 0.9524 - recall_1: 0.8000
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 12ms/step - loss: 15.8475 - auc_90: 0.3608 - recall_0: 0.5165 - recall_1: 0.3571
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 15.2009 - auc_90: 0.3985 - recall_0: 0.5165 - recall_1: 0.2619
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 14.5783 - auc_90: 0.4606 - recall_0: 0.5604 - recall_1: 0.3333
# Epoch 4/100
# 4/4 [==============================] - 0s 17ms/step - loss: 13.9469 - auc_90: 0.5761 - recall_0: 0.7692 - recall_1: 0.4048
# Epoch 5/100
# 4/4 [==============================] - 0s 15ms/step - loss: 13.3515 - auc_90: 0.6497 - recall_0: 0.7912 - recall_1: 0.4524
# Epoch 6/100
# 4/4 [==============================] - 0s 14ms/step - loss: 12.7541 - auc_90: 0.7207 - recall_0: 0.8352 - recall_1: 0.5238
# Epoch 7/100
# 1/4 [======>.......................] - ETA: 0s - loss: 12.4108 - auc_90: 0.6406 - recall_0: 0.8750 - recall_1: 0.3333Restoring model weights from the end of the best epoch: 2.
# 4/4 [==============================] - 0s 16ms/step - loss: 12.1826 - auc_90: 0.7610 - recall_0: 0.8901 - recall_1: 0.4286
# Epoch 7: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 13ms/step - loss: 16.1450 - auc_91: 0.4198 - recall_0: 0.4624 - recall_1: 0.5250
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 15.4779 - auc_91: 0.5567 - recall_0: 0.5591 - recall_1: 0.5000
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 14.8480 - auc_91: 0.5741 - recall_0: 0.6989 - recall_1: 0.4000
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 14.2105 - auc_91: 0.7565 - recall_0: 0.8065 - recall_1: 0.5500
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 13.5961 - auc_91: 0.8116 - recall_0: 0.8172 - recall_1: 0.5000
# Epoch 6/100
# 4/4 [==============================] - 0s 14ms/step - loss: 12.9874 - auc_91: 0.8757 - recall_0: 0.9355 - recall_1: 0.5250
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 12.4019 - auc_91: 0.9378 - recall_0: 0.9462 - recall_1: 0.6250
# Epoch 8/100
# 1/4 [======>.......................] - ETA: 0s - loss: 12.0264 - auc_91: 0.9455 - recall_0: 0.9200 - recall_1: 0.6364Restoring model weights from the end of the best epoch: 3.
# 4/4 [==============================] - 0s 14ms/step - loss: 11.8308 - auc_91: 0.9575 - recall_0: 0.9570 - recall_1: 0.5250
# Epoch 8: early stopping
# Epoch 1/100
# 15/15 [==============================] - 4s 15ms/step - loss: 15.1462 - auc_92: 0.4214 - recall_0: 0.5666 - recall_1: 0.3644
# Epoch 2/100
# 15/15 [==============================] - 0s 13ms/step - loss: 12.9099 - auc_92: 0.6191 - recall_0: 0.8225 - recall_1: 0.3814
# Epoch 3/100
# 15/15 [==============================] - 0s 15ms/step - loss: 10.8611 - auc_92: 0.7642 - recall_0: 0.9215 - recall_1: 0.4576
# Epoch 4/100
# 15/15 [==============================] - 0s 14ms/step - loss: 8.9964 - auc_92: 0.8137 - recall_0: 0.9317 - recall_1: 0.4703
# Epoch 5/100
# 15/15 [==============================] - 0s 15ms/step - loss: 7.3015 - auc_92: 0.8458 - recall_0: 0.9249 - recall_1: 0.5381
# Epoch 6/100
# 15/15 [==============================] - ETA: 0s - loss: 5.7800 - auc_92: 0.8702 - recall_0: 0.9147 - recall_1: 0.6186Restoring model weights from the end of the best epoch: 1.
# 15/15 [==============================] - 0s 18ms/step - loss: 5.7800 - auc_92: 0.8702 - recall_0: 0.9147 - recall_1: 0.6186
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 20ms/step - loss: 0.6472 - auc_93: 0.6650 - recall_0: 0.8095 - recall_1: 0.4857
# Epoch 2/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5132 - auc_93: 0.8949 - recall_0: 0.9365 - recall_1: 0.6429
# Epoch 3/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.4132 - auc_93: 0.9624 - recall_0: 0.9524 - recall_1: 0.7714
# Epoch 4/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3427 - auc_93: 0.9802 - recall_0: 0.9524 - recall_1: 0.8286
# Epoch 5/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2838 - auc_93: 0.9858 - recall_0: 0.9524 - recall_1: 0.8714
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2522 - auc_93: 0.9821 - recall_0: 0.9545 - recall_1: 0.9286Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2531 - auc_93: 0.9875 - recall_0: 0.9524 - recall_1: 0.8571
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 13ms/step - loss: 0.6599 - auc_94: 0.6600 - recall_0: 0.6484 - recall_1: 0.6190
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5794 - auc_94: 0.7737 - recall_0: 0.8132 - recall_1: 0.5952
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5144 - auc_94: 0.8591 - recall_0: 0.8901 - recall_1: 0.7143
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4528 - auc_94: 0.9014 - recall_0: 0.9560 - recall_1: 0.7381
# Epoch 5/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4194 - auc_94: 0.8929 - recall_0: 0.9560 - recall_1: 0.7143
# Epoch 6/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3814 - auc_94: 0.9050 - recall_0: 0.9560 - recall_1: 0.7857
# Epoch 7/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3812 - auc_94: 0.8837 - recall_0: 0.9583 - recall_1: 0.7500Restoring model weights from the end of the best epoch: 2.
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3275 - auc_94: 0.9354 - recall_0: 0.9451 - recall_1: 0.8810
# Epoch 7: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 15ms/step - loss: 0.7127 - auc_95: 0.4728 - recall_0: 0.5269 - recall_1: 0.4000
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6083 - auc_95: 0.7310 - recall_0: 0.7419 - recall_1: 0.5500
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5242 - auc_95: 0.8515 - recall_0: 0.8710 - recall_1: 0.5750
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4619 - auc_95: 0.9207 - recall_0: 0.8925 - recall_1: 0.6750
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4058 - auc_95: 0.9445 - recall_0: 0.9247 - recall_1: 0.6500
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.4051 - auc_95: 0.9436 - recall_0: 0.9600 - recall_1: 0.6364Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3551 - auc_95: 0.9555 - recall_0: 0.9570 - recall_1: 0.7000
# Epoch 6: early stopping
# Epoch 1/100
# 15/15 [==============================] - 4s 10ms/step - loss: 0.6068 - auc_96: 0.7501 - recall_0: 0.7406 - recall_1: 0.6271
# Epoch 2/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4754 - auc_96: 0.8769 - recall_0: 0.8771 - recall_1: 0.6992
# Epoch 3/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3957 - auc_96: 0.9128 - recall_0: 0.9044 - recall_1: 0.7415
# Epoch 4/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3425 - auc_96: 0.9332 - recall_0: 0.9010 - recall_1: 0.8136
# Epoch 5/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2945 - auc_96: 0.9497 - recall_0: 0.9249 - recall_1: 0.8517
# Epoch 6/100
# 12/15 [=======================>......] - ETA: 0s - loss: 0.2320 - auc_96: 0.9693 - recall_0: 0.9391 - recall_1: 0.8960Restoring model weights from the end of the best epoch: 1.
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2373 - auc_96: 0.9675 - recall_0: 0.9386 - recall_1: 0.8856
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 18ms/step - loss: 6.6971 - auc_97: 0.8324 - recall_0: 0.8095 - recall_1: 0.7429
# Epoch 2/100
# 4/4 [==============================] - 0s 17ms/step - loss: 6.3730 - auc_97: 0.9536 - recall_0: 0.9683 - recall_1: 0.7714
# Epoch 3/100
# 4/4 [==============================] - 0s 18ms/step - loss: 6.0392 - auc_97: 0.9782 - recall_0: 0.9524 - recall_1: 0.8714
# Epoch 4/100
# 4/4 [==============================] - 0s 28ms/step - loss: 5.7438 - auc_97: 0.9813 - recall_0: 0.9841 - recall_1: 0.9143
# Epoch 5/100
# 4/4 [==============================] - 0s 18ms/step - loss: 5.4624 - auc_97: 0.9861 - recall_0: 0.9683 - recall_1: 0.8857
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 5.2582 - auc_97: 1.0000 - recall_0: 1.0000 - recall_1: 0.9286Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 22ms/step - loss: 5.2034 - auc_97: 0.9796 - recall_0: 0.9683 - recall_1: 0.8857
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 8s 19ms/step - loss: 6.7733 - auc_98: 0.5874 - recall_0: 0.5495 - recall_1: 0.5714
# Epoch 2/100
# 4/4 [==============================] - 0s 17ms/step - loss: 6.4482 - auc_98: 0.7688 - recall_0: 0.7692 - recall_1: 0.6667
# Epoch 3/100
# 4/4 [==============================] - 0s 14ms/step - loss: 6.1542 - auc_98: 0.8319 - recall_0: 0.8242 - recall_1: 0.7143
# Epoch 4/100
# 4/4 [==============================] - 0s 14ms/step - loss: 5.8653 - auc_98: 0.8745 - recall_0: 0.8462 - recall_1: 0.7381
# Epoch 5/100
# 4/4 [==============================] - 0s 17ms/step - loss: 5.5851 - auc_98: 0.8965 - recall_0: 0.9231 - recall_1: 0.7143
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 5.3720 - auc_98: 0.9942 - recall_0: 0.9615 - recall_1: 1.0000Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 15ms/step - loss: 5.3085 - auc_98: 0.9307 - recall_0: 0.9341 - recall_1: 0.7857
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 15ms/step - loss: 6.7399 - auc_99: 0.5190 - recall_0: 0.5484 - recall_1: 0.4750
# Epoch 2/100
# 4/4 [==============================] - 0s 15ms/step - loss: 6.4340 - auc_99: 0.7042 - recall_0: 0.6989 - recall_1: 0.5750
# Epoch 3/100
# ...
# Epoch 6/100
# 3/4 [=====================>........] - ETA: 0s - loss: 13.1288 - auc_257: 0.9279 - recall_0: 0.8814 - recall_1: 0.7347Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 33ms/step - loss: 13.0975 - auc_257: 0.9345 - recall_0: 0.8889 - recall_1: 0.7414
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 31ms/step - loss: 15.8909 - auc_258: 0.5677 - recall_0: 0.5952 - recall_1: 0.5676
# Epoch 2/100
# 4/4 [==============================] - 0s 33ms/step - loss: 15.2419 - auc_258: 0.6279 - recall_0: 0.6429 - recall_1: 0.4595
# Epoch 3/100
# 4/4 [==============================] - 0s 28ms/step - loss: 14.6031 - auc_258: 0.7260 - recall_0: 0.7976 - recall_1: 0.5676
# Epoch 4/100
# 4/4 [==============================] - 0s 28ms/step - loss: 13.9954 - auc_258: 0.7375 - recall_0: 0.8095 - recall_1: 0.5135
# Epoch 5/100
# 4/4 [==============================] - 0s 27ms/step - loss: 13.3750 - auc_258: 0.8298 - recall_0: 0.8929 - recall_1: 0.6216
# Epoch 6/100
# 4/4 [==============================] - 0s 27ms/step - loss: 12.7866 - auc_258: 0.8285 - recall_0: 0.9167 - recall_1: 0.5946
# Epoch 7/100
# 4/4 [==============================] - ETA: 0s - loss: 12.2244 - auc_258: 0.8380 - recall_0: 0.9405 - recall_1: 0.6486Restoring model weights from the end of the best epoch: 2.
# 4/4 [==============================] - 0s 29ms/step - loss: 12.2244 - auc_258: 0.8380 - recall_0: 0.9405 - recall_1: 0.6486
# Epoch 7: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 34ms/step - loss: 16.1254 - auc_259: 0.5656 - recall_0: 0.5432 - recall_1: 0.6000
# Epoch 2/100
# 4/4 [==============================] - 0s 30ms/step - loss: 15.4585 - auc_259: 0.6955 - recall_0: 0.6790 - recall_1: 0.5750
# Epoch 3/100
# 4/4 [==============================] - 0s 34ms/step - loss: 14.8315 - auc_259: 0.7248 - recall_0: 0.6667 - recall_1: 0.6250
# Epoch 4/100
# 4/4 [==============================] - 0s 31ms/step - loss: 14.2085 - auc_259: 0.7569 - recall_0: 0.8148 - recall_1: 0.5000
# Epoch 5/100
# 4/4 [==============================] - 0s 32ms/step - loss: 13.6145 - auc_259: 0.7738 - recall_0: 0.7778 - recall_1: 0.5500
# Epoch 6/100
# 4/4 [==============================] - 0s 33ms/step - loss: 13.0146 - auc_259: 0.8140 - recall_0: 0.8765 - recall_1: 0.5000
# Epoch 7/100
# 4/4 [==============================] - 0s 31ms/step - loss: 12.4430 - auc_259: 0.8034 - recall_0: 0.9259 - recall_1: 0.4000
# Epoch 8/100
# 4/4 [==============================] - 0s 29ms/step - loss: 11.8677 - auc_259: 0.8650 - recall_0: 0.9877 - recall_1: 0.4500
# Epoch 9/100
# 4/4 [==============================] - 0s 31ms/step - loss: 11.3202 - auc_259: 0.8801 - recall_0: 0.9753 - recall_1: 0.4500
# Epoch 10/100
# 4/4 [==============================] - 0s 31ms/step - loss: 10.7804 - auc_259: 0.8901 - recall_0: 0.9630 - recall_1: 0.4500
# Epoch 11/100
# 4/4 [==============================] - 0s 29ms/step - loss: 10.2531 - auc_259: 0.9321 - recall_0: 0.9877 - recall_1: 0.4250
# Epoch 12/100
# 3/4 [=====================>........] - ETA: 0s - loss: 9.7473 - auc_259: 0.9609 - recall_0: 0.9863 - recall_1: 0.4571Restoring model weights from the end of the best epoch: 7.
# 4/4 [==============================] - 0s 33ms/step - loss: 9.7298 - auc_259: 0.9534 - recall_0: 0.9877 - recall_1: 0.4250
# Epoch 12: early stopping
# Epoch 1/100
# 15/15 [==============================] - 4s 24ms/step - loss: 15.0134 - auc_260: 0.7184 - recall_0: 0.7406 - recall_1: 0.5848
# Epoch 2/100
# 15/15 [==============================] - 0s 24ms/step - loss: 12.7779 - auc_260: 0.7999 - recall_0: 0.8567 - recall_1: 0.6071
# Epoch 3/100
# 15/15 [==============================] - 0s 25ms/step - loss: 10.7157 - auc_260: 0.8544 - recall_0: 0.9147 - recall_1: 0.5804
# Epoch 4/100
# 15/15 [==============================] - 0s 25ms/step - loss: 8.8402 - auc_260: 0.8679 - recall_0: 0.9249 - recall_1: 0.5848
# Epoch 5/100
# 15/15 [==============================] - 0s 23ms/step - loss: 7.1562 - auc_260: 0.8786 - recall_0: 0.9215 - recall_1: 0.6830
# Epoch 6/100
# 15/15 [==============================] - 0s 22ms/step - loss: 5.6810 - auc_260: 0.8816 - recall_0: 0.8771 - recall_1: 0.7366
# Epoch 7/100
# 15/15 [==============================] - 0s 28ms/step - loss: 4.3860 - auc_260: 0.9005 - recall_0: 0.8840 - recall_1: 0.7812
# Epoch 8/100
# 15/15 [==============================] - ETA: 0s - loss: 3.2942 - auc_260: 0.9053 - recall_0: 0.8771 - recall_1: 0.7589Restoring model weights from the end of the best epoch: 3.
# 15/15 [==============================] - 0s 30ms/step - loss: 3.2942 - auc_260: 0.9053 - recall_0: 0.8771 - recall_1: 0.7589
# Epoch 8: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 31ms/step - loss: 0.6941 - auc_261: 0.5475 - recall_0: 0.5873 - recall_1: 0.6034
# Epoch 2/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.5734 - auc_261: 0.8878 - recall_0: 0.8095 - recall_1: 0.8103
# Epoch 3/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4768 - auc_261: 0.9559 - recall_0: 0.9048 - recall_1: 0.8793
# Epoch 4/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4047 - auc_261: 0.9709 - recall_0: 0.9524 - recall_1: 0.8448
# Epoch 5/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3540 - auc_261: 0.9781 - recall_0: 0.9524 - recall_1: 0.8793
# Epoch 6/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.3032 - auc_261: 0.9822 - recall_0: 0.9492 - recall_1: 0.8776Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2982 - auc_261: 0.9847 - recall_0: 0.9524 - recall_1: 0.8793
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 24ms/step - loss: 0.7744 - auc_262: 0.3163 - recall_0: 0.3690 - recall_1: 0.4054
# Epoch 2/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.6794 - auc_262: 0.5579 - recall_0: 0.6310 - recall_1: 0.4324
# Epoch 3/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6051 - auc_262: 0.7950 - recall_0: 0.8571 - recall_1: 0.5946
# Epoch 4/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.5372 - auc_262: 0.9104 - recall_0: 0.9524 - recall_1: 0.7297
# Epoch 5/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4631 - auc_262: 0.9521 - recall_0: 0.9643 - recall_1: 0.7568
# Epoch 6/100
# 4/4 [==============================] - ETA: 0s - loss: 0.4048 - auc_262: 0.9715 - recall_0: 1.0000 - recall_1: 0.7027Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 29ms/step - loss: 0.4048 - auc_262: 0.9715 - recall_0: 1.0000 - recall_1: 0.7027
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 29ms/step - loss: 0.5982 - auc_263: 0.8042 - recall_0: 0.7407 - recall_1: 0.7250
# Epoch 2/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.5136 - auc_263: 0.9284 - recall_0: 0.9506 - recall_1: 0.6750
# Epoch 3/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4533 - auc_263: 0.9579 - recall_0: 0.9259 - recall_1: 0.7750
# Epoch 4/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3950 - auc_263: 0.9755 - recall_0: 0.9753 - recall_1: 0.7250
# Epoch 5/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3421 - auc_263: 0.9844 - recall_0: 0.9877 - recall_1: 0.8750
# Epoch 6/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3023 - auc_263: 0.9906 - recall_0: 0.9877 - recall_1: 0.8000
# Epoch 7/100
# 3/4 [=====================>........] - ETA: 0s - loss: 0.2663 - auc_263: 0.9898 - recall_0: 0.9861 - recall_1: 0.8333Restoring model weights from the end of the best epoch: 2.
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2622 - auc_263: 0.9912 - recall_0: 0.9877 - recall_1: 0.8250
# Epoch 7: early stopping
# Epoch 1/100
# 15/15 [==============================] - 3s 23ms/step - loss: 0.6514 - auc_264: 0.6366 - recall_0: 0.6792 - recall_1: 0.5268
# Epoch 2/100
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4992 - auc_264: 0.8579 - recall_0: 0.8567 - recall_1: 0.6518
# Epoch 3/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.4124 - auc_264: 0.9129 - recall_0: 0.8942 - recall_1: 0.7768
# Epoch 4/100
# 15/15 [==============================] - 0s 20ms/step - loss: 0.3443 - auc_264: 0.9398 - recall_0: 0.9181 - recall_1: 0.7991
# Epoch 5/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.2842 - auc_264: 0.9532 - recall_0: 0.9147 - recall_1: 0.8705
# Epoch 6/100
# 13/15 [=========================>....] - ETA: 0s - loss: 0.2235 - auc_264: 0.9763 - recall_0: 0.9582 - recall_1: 0.8634Restoring model weights from the end of the best epoch: 1.
# 15/15 [==============================] - 0s 21ms/step - loss: 0.2332 - auc_264: 0.9707 - recall_0: 0.9522 - recall_1: 0.8661
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 27ms/step - loss: 6.9061 - auc_265: 0.3221 - recall_0: 0.1587 - recall_1: 0.5172
# Epoch 2/100
# 4/4 [==============================] - 0s 28ms/step - loss: 6.5462 - auc_265: 0.7105 - recall_0: 0.6508 - recall_1: 0.6552
# Epoch 3/100
# 4/4 [==============================] - 0s 28ms/step - loss: 6.1935 - auc_265: 0.9458 - recall_0: 0.8730 - recall_1: 0.8276
# Epoch 4/100
# 4/4 [==============================] - 0s 28ms/step - loss: 5.8987 - auc_265: 0.9577 - recall_0: 0.9365 - recall_1: 0.8448
# Epoch 5/100
# 4/4 [==============================] - 0s 23ms/step - loss: 5.6182 - auc_265: 0.9632 - recall_0: 0.9524 - recall_1: 0.7931
# Epoch 6/100
# 4/4 [==============================] - ETA: 0s - loss: 5.3457 - auc_265: 0.9788 - recall_0: 0.9524 - recall_1: 0.7931Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 27ms/step - loss: 5.3457 - auc_265: 0.9788 - recall_0: 0.9524 - recall_1: 0.7931
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 40ms/step - loss: 6.8094 - auc_266: 0.5164 - recall_0: 0.5476 - recall_1: 0.5676
# Epoch 2/100
# 4/4 [==============================] - 0s 39ms/step - loss: 6.4804 - auc_266: 0.6969 - recall_0: 0.6548 - recall_1: 0.6216
# Epoch 3/100
# 4/4 [==============================] - 0s 52ms/step - loss: 6.1807 - auc_266: 0.7896 - recall_0: 0.7857 - recall_1: 0.6216
# Epoch 4/100
# 4/4 [==============================] - 0s 51ms/step - loss: 5.8838 - auc_266: 0.8647 - recall_0: 0.8452 - recall_1: 0.5946
# Epoch 5/100
# 4/4 [==============================] - 0s 52ms/step - loss: 5.5994 - auc_266: 0.9181 - recall_0: 0.9167 - recall_1: 0.6757
# Epoch 6/100
# 4/4 [==============================] - ETA: 0s - loss: 5.3190 - auc_266: 0.9360 - recall_0: 0.9405 - recall_1: 0.6216Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 60ms/step - loss: 5.3190 - auc_266: 0.9360 - recall_0: 0.9405 - recall_1: 0.6216
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 24ms/step - loss: 6.8670 - auc_267: 0.5267 - recall_0: 0.5679 - recall_1: 0.5500
# Epoch 2/100
# 4/4 [==============================] - 0s 25ms/step - loss: 6.5410 - auc_267: 0.7381 - recall_0: 0.7531 - recall_1: 0.6500
# Epoch 3/100
# 4/4 [==============================] - 0s 25ms/step - loss: 6.2455 - auc_267: 0.8164 - recall_0: 0.9136 - recall_1: 0.6000
# Epoch 4/100
# 4/4 [==============================] - 0s 29ms/step - loss: 5.9548 - auc_267: 0.8608 - recall_0: 0.9383 - recall_1: 0.5500
# Epoch 5/100
# 4/4 [==============================] - 0s 25ms/step - loss: 5.6815 - auc_267: 0.8728 - recall_0: 0.9383 - recall_1: 0.6500
# Epoch 6/100
# 4/4 [==============================] - ETA: 0s - loss: 5.3970 - auc_267: 0.9071 - recall_0: 0.9383 - recall_1: 0.6250Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 26ms/step - loss: 5.3970 - auc_267: 0.9071 - recall_0: 0.9383 - recall_1: 0.6250
# Epoch 6: early stopping
# Epoch 1/100
# 15/15 [==============================] - 4s 25ms/step - loss: 6.4560 - auc_268: 0.5451 - recall_0: 0.7509 - recall_1: 0.3482
# Epoch 2/100
# 15/15 [==============================] - 0s 23ms/step - loss: 5.4413 - auc_268: 0.8330 - recall_0: 0.9420 - recall_1: 0.4911
# Epoch 3/100
# 15/15 [==============================] - 0s 24ms/step - loss: 4.5431 - auc_268: 0.8865 - recall_0: 0.9454 - recall_1: 0.5759
# Epoch 4/100
# 15/15 [==============================] - 0s 23ms/step - loss: 3.7326 - auc_268: 0.9080 - recall_0: 0.9488 - recall_1: 0.6429
# Epoch 5/100
# 15/15 [==============================] - 0s 22ms/step - loss: 3.0086 - auc_268: 0.9113 - recall_0: 0.9283 - recall_1: 0.7768
# Epoch 6/100
# 14/15 [===========================>..] - ETA: 0s - loss: 2.3789 - auc_268: 0.9397 - recall_0: 0.9190 - recall_1: 0.8091Restoring model weights from the end of the best epoch: 1.
# 15/15 [==============================] - 0s 25ms/step - loss: 2.3821 - auc_268: 0.9328 - recall_0: 0.9181 - recall_1: 0.7991
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 24ms/step - loss: 19.0397 - auc_269: 0.6550 - recall_0: 0.6984 - recall_1: 0.5172
# Epoch 2/100
# 4/4 [==============================] - 0s 23ms/step - loss: 18.1529 - auc_269: 0.8458 - recall_0: 0.8730 - recall_1: 0.6897
# Epoch 3/100
# 4/4 [==============================] - 0s 27ms/step - loss: 17.3155 - auc_269: 0.8857 - recall_0: 0.8889 - recall_1: 0.7586
# Epoch 4/100
# 4/4 [==============================] - 0s 30ms/step - loss: 16.4831 - auc_269: 0.9221 - recall_0: 0.9206 - recall_1: 0.8276
# Epoch 5/100
# 4/4 [==============================] - 0s 31ms/step - loss: 15.6821 - auc_269: 0.9308 - recall_0: 0.9524 - recall_1: 0.8103
# Epoch 6/100
# 4/4 [==============================] - ETA: 0s - loss: 14.8978 - auc_269: 0.9465 - recall_0: 0.9683 - recall_1: 0.8966Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 30ms/step - loss: 14.8978 - auc_269: 0.9465 - recall_0: 0.9683 - recall_1: 0.8966
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 3s 26ms/step - loss: 18.7053 - auc_270: 0.6318 - recall_0: 0.5476 - recall_1: 0.5676
# Epoch 2/100
# 4/4 [==============================] - 0s 29ms/step - loss: 17.8217 - auc_270: 0.7375 - recall_0: 0.6786 - recall_1: 0.5946
# Epoch 3/100
# 4/4 [==============================] - 0s 26ms/step - loss: 16.9936 - auc_270: 0.7736 - recall_0: 0.7381 - recall_1: 0.6757
# Epoch 4/100
# 4/4 [==============================] - 0s 27ms/step - loss: 16.1569 - auc_270: 0.8588 - recall_0: 0.8452 - recall_1: 0.7297
# Epoch 5/100
# 4/4 [==============================] - 0s 42ms/step - loss: 15.3611 - auc_270: 0.8768 - recall_0: 0.9167 - recall_1: 0.5946
# Epoch 6/100
# 3/4 [=====================>........] - ETA: 0s - loss: 14.5939 - auc_270: 0.9338 - recall_0: 0.9474 - recall_1: 0.6875Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 39ms/step - loss: 14.5564 - auc_270: 0.9311 - recall_0: 0.9524 - recall_1: 0.7027
# Epoch 6: early stopping
# Epoch 1/100
# 4/4 [==============================] - 4s 26ms/step - loss: 19.1934 - auc_271: 0.3980 - recall_0: 0.5185 - recall_1: 0.2250
# Epoch 2/100
# 4/4 [==============================] - 0s 26ms/step - loss: 18.3111 - auc_271: 0.6057 - recall_0: 0.7531 - recall_1: 0.4250
# Epoch 3/100
# 4/4 [==============================] - 0s 27ms/step - loss: 17.4673 - auc_271: 0.6750 - recall_0: 0.8148 - recall_1: 0.4750
# Epoch 4/100
# 4/4 [==============================] - 0s 31ms/step - loss: 16.6537 - auc_271: 0.7319 - recall_0: 0.8519 - recall_1: 0.4750
# Epoch 5/100
# 4/4 [==============================] - 0s 33ms/step - loss: 15.8431 - auc_271: 0.8375 - recall_0: 0.9259 - recall_1: 0.4750
# Epoch 6/100
# 4/4 [==============================] - ETA: 0s - loss: 15.0594 - auc_271: 0.8631 - recall_0: 0.9136 - recall_1: 0.4750Restoring model weights from the end of the best epoch: 1.
# 4/4 [==============================] - 0s 30ms/step - loss: 15.0594 - auc_271: 0.8631 - recall_0: 0.9136 - recall_1: 0.4750
# Epoch 6: early stopping
# Epoch 1/100

# %% [markdown]
# ## 2. Model Selection

# %% [markdown]
# ## Concatenate results of all candidate models from all folders
# * concatenate all results into df_result.pkl file
# * group and average df_result.pkl by certain model specifications and early stopping options and save it to df_selection.pkl file

# %%
folders=[x for x in os.listdir(path+"/model") if ('change' in x)]

for i, folder in enumerate(folders):
  folder_path=path+'/model/{}'.format(folder)
  with open(folder_path+'/history_dict.pkl','rb') as f:
    history_dict=pickle.load(f)

  ytype=folder.split("_")[2]
  model_type=folder.split("_")[3]
  if folder.split("_")[-1]=='es':
    es=True
  else:
    es=False

  df_tmp=pd.DataFrame(history_dict)
  df_tmp['ytype']=ytype
  df_tmp['model_type']=model_type
  df_tmp['early_stopping']=es

  if i==0:
    df_result=df_tmp
  else:
    df_result=pd.concat([df_result, df_tmp])

## model selection: according to cross validation recall, auc scores
df_result['macro_recall']=(df_result['recall_0']+df_result['recall_1'])/2
df_selection=df_result.groupby(['model','early_stopping']).mean().sort_values(['macro_recall'], ascending=[False])

with open(path+'/model/df_result.pkl', 'wb') as f:
  pickle.dump(df_result, f)

with open(path+'/model/df_selection.pkl', 'wb') as f:
  pickle.dump(df_selection, f)
# Out:
# <ipython-input-48-99fc569393a9>:27: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_selection=df_result.groupby(['model','early_stopping']).mean().sort_values(['macro_recall'], ascending=[False])

# %%
with open(path+'/model/df_selection.pkl', 'rb') as f:
  df_selection = pickle.load(f)

model_name=df_selection.iloc[0].name[0]
es=df_selection.iloc[0].name[1]
print(model_name, es)

df_selection=df_selection.reset_index()
df_selection.head(10)
# Out:
# clf_y_oecd_lstm_24_b12_ep100_h10_d0.2_None True
#                                            model  early_stopping  val  \
# 0     clf_y_oecd_lstm_24_b12_ep100_h10_d0.2_None            True  1.0
# 1      clf_y_oecd_gru_18_b12_ep100_h10_d0.2_None            True  1.0
# 2   clf_y_oecd_gru_18_b12_ep100_h10_d0.2_L1_0.01            True  1.0
# 3     clf_y_oecd_lstm_12_b12_ep100_h30_d0.2_None           False  1.0
# 4      clf_y_oecd_gru_12_b12_ep100_h30_d0.2_None            True  1.0
# 5  clf_y_oecd_lstm_12_b12_ep100_h50_d0.2_L1_0.03            True  1.0
# 6     clf_y_oecd_lstm_18_b12_ep100_h70_d0.2_None            True  1.0
# 7     clf_y_oecd_lstm_12_b12_ep100_h20_d0.2_None           False  1.0
# 8      clf_y_oecd_gru_12_b12_ep100_h30_d0.2_None           False  1.0
# 9      clf_y_oecd_gru_12_b12_ep100_h20_d0.2_None            True  1.0
#
#         auc  recall_0  recall_1  recall_2  final_auc  final_recall_0  \
# 0  0.634259  0.666667  0.602564    -100.0   0.870536        0.732143
# 1  0.433333  0.518519  0.680702    -100.0   0.642857        0.803571
# 2  0.585185  0.629630  0.563158    -100.0   0.886161        0.589286
# 3  0.447917  0.666667  0.463333    -100.0   0.888393        0.732143
# 4  0.464120  0.629630  0.476667    -100.0   0.863839        0.821429
# 5  0.519676  0.666667  0.437500    -100.0   0.957589        0.696429
# 6  0.420370  0.666667  0.428070    -100.0   0.908482        0.714286
# 7  0.483796  0.666667  0.415833    -100.0   0.852679        0.785714
# 8  0.431713  0.666667  0.410000    -100.0   0.872768        0.589286
# 9  0.439815  0.592593  0.480833    -100.0   0.866072        0.625000
#
#    final_recall_1  final_recall_2  macro_recall
# 0            1.00          -100.0      0.634615
# 1            0.25          -100.0      0.599610
# 2            1.00          -100.0      0.596394
# 3            1.00          -100.0      0.565000
# 4            0.75          -100.0      0.553148
# 5            1.00          -100.0      0.552083
# 6            1.00          -100.0      0.547368
# 7            0.75          -100.0      0.541250
# 8            1.00          -100.0      0.538333
# 9            0.75          -100.0      0.536713
